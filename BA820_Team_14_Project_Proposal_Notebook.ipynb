# %% [markdown]
# <a href="https://colab.research.google.com/github/BackBencher2424/BA820_Team_14_Project/blob/main/BA820_Team_14_Project_Proposal_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Code Trends, Quantified: Mapping the Programming Language Ecosystem**
# ***Section:** B1* <br>
# ***Team:** 14* <br>
# ***Team Members:** Drishti Chulani, Arshdeep Singh Oberoi, Ahrar Karim, Vishesh Goyal* <br>
#
# ***Link to Colab Notebook (EDA Primary Dataset):** [Click Here to Access the Colab Notebook for Primary Dataset EDA](https://colab.research.google.com/drive/1KR8Z4ZS2_CrUe3nTaPI5AWtBwOZ6QDQn?usp=sharing)* <br>
#
# ***Link to Colab Notebook (EDA Backup Dataset):** [Click Here to Access the Colab Notebook for Backup Dataset EDA](https://)* <br>
#
# ***Link to Github Repo:** [Click Here to Access the Github Repo](https://github.com/BackBencher2424/BA820_Team_14_Project)*
#
# ***Primary Dataset:** [Programming Languages](https://github.com/rfordatascience/tidytuesday/tree/main/data/2023/2023-03-21)*

# %% [markdown]
# ##**1. Primary Dataset**

# %% [markdown]
# ###**1.1. Project Motivation and Preliminary Exploratory Data Analysis (EDA)**

# %% [markdown]
# ###**1.2.  Domain / Business Questions (Core Section)**

# %% [markdown]
# ##**2. Backup Dataset**

# %% [markdown]
# ###**2.1. Project Motivation and Preliminary Exploratory Data Analysis (EDA)**

# %% [markdown]
# ###**2.2.  Domain / Business Questions (Core Section)**
