# %% [markdown]
# <a href="https://colab.research.google.com/github/BackBencher2424/BA820_Team_14_Project/blob/main/ba820_m2_q2_drishti_chulani.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Code Trends, Quantified: Mapping the Programming Language Ecosystem**
# ***Section:** B1* <br>
# ***Team:** 14* <br>
# ***Team Members:** Drishti Chulani, Arshdeep Singh Oberoi, Ahrar Karim, Vishesh Goyal* <br><br>
#
# ***Link to Proposal Notebook (BA820_Team_14_Project_Proposal_Notebook.ipynb):** [Primary Dataset EDA Notebook](https://colab.research.google.com/drive/1irElxdNYp_Hh08p4MeOGdafvt_d1KsT7?usp=sharing)* <br>
# ***Link to Colab Notebook (EDA Primary Dataset):** [Primary Dataset EDA Notebook](https://colab.research.google.com/drive/1KR8Z4ZS2_CrUe3nTaPI5AWtBwOZ6QDQn?usp=sharing)* <br>
# ***Link to Colab Notebook (EDA Backup Dataset):** [Backup Dataset EDA Notebook](https://colab.research.google.com/drive/1hv-sx-c6sdlDacv2ooOj7u4S3TcMz_Yb?usp=sharing)* <br>
# ***Primary Dataset:** [Programming Languages Dataset Link](https://github.com/rfordatascience/tidytuesday/tree/main/data/2023/2023-03-21)*<br>
# ***Backup Dataset:** [Bob Ross Paintings Dataset Link](https://github.com/rfordatascience/tidytuesday/tree/main/data/2023/2023-02-21)*<br>
# ***Link to Github Repo:** [Github Repo Link](https://github.com/BackBencher2424/BA820_Team_14_Project)*

# %% [markdown]
# ##**1. Setup**

# %% [markdown]
# ###***Importing Libraries***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from collections import Counter
from IPython.display import display

# %% [markdown]
# ###***Loading Dataset***

# %%
path = "/content/languages.csv"
df = pd.read_csv(path) # Loads the primary dataset to the runtime

# %% [markdown]
# ##**2. Preprocessing**

# %% [markdown]
# ###***Standerdizing and Exploring the Dataset***

# %%
df.columns = [c.strip().lower() for c in df.columns] # Standerdizes the columns, strip() —->> removes any trailing or leading spaces, lower() -->> makes all the column names lowercase

# %%
print("Shape (rows, cols):", df.shape) #Gives number of Rows and Columns
# Out:
# Shape (rows, cols): (4303, 49)

# %%
df.head(10) # Gives the first 10 entries of the dataset
# Out:
#       pldb_id       title description           type  appeared  \
# 0        java        Java         NaN             pl      1995
# 1  javascript  JavaScript         NaN             pl      1995
# 2           c           C         NaN             pl      1972
# 3      python      Python         NaN             pl      1991
# 4         sql         SQL         NaN  queryLanguage      1974
# 5         cpp         C++         NaN             pl      1985
# 6        html        HTML         NaN     textMarkup      1991
# 7         xml         XML         NaN   dataNotation      1996
# 8         php         PHP         NaN             pl      1995
# 9        perl        Perl         NaN             pl      1987
#
#                                     creators                   website  \
# 0                              James Gosling  https://oracle.com/java/
# 1                               Brendan Eich                       NaN
# 2                             Dennis Ritchie                       NaN
# 3                           Guido van Rossum   https://www.python.org/
# 4  Donald D. Chamberlin and Raymond F. Boyce                       NaN
# 5                          Bjarne Stroustrup        http://isocpp.org/
# 6                            Tim Berners-Lee                       NaN
# 7                                        NaN                       NaN
# 8                             Rasmus Lerdorf           https://php.net
# 9                                 Larry Wall      https://www.perl.org
#
#   domain_name  domain_name_registered  \
# 0         NaN                     NaN
# 1         NaN                     NaN
# 2         NaN                     NaN
# 3  python.org                  1995.0
# 4         NaN                     NaN
# 5  isocpp.org                  2012.0
# 6         NaN                     NaN
# 7         NaN                     NaN
# 8     php.net                  1997.0
# 9    perl.org                  1995.0
#
#                                            reference  ...  \
# 0                                                NaN  ...
# 1       https://www.w3schools.com/js/js_reserved.asp  ...
# 2   http://www.c4learn.com/c-programming/c-keywords/  ...
# 3  https://www.programiz.com/python-programming/k...  ...
# 4                                                NaN  ...
# 5                                                NaN  ...
# 6                                                NaN  ...
# 7                                                NaN  ...
# 8     http://php.net/manual/en/reserved.keywords.php  ...
# 9                                                NaN  ...
#
#    features_has_semantic_indentation  features_has_line_comments  \
# 0                              False                        True
# 1                              False                        True
# 2                              False                        True
# 3                               True                        True
# 4                              False                        True
# 5                                NaN                         NaN
# 6                              False                       False
# 7                              False                       False
# 8                              False                        True
# 9                              False                        True
#
#    line_comment_token  last_activity number_of_users  number_of_jobs  \
# 0                  //           2022         5550123           85206
# 1                  //           2022         5962666           63993
# 2                  //           2022         3793768           59919
# 3                   #           2022         2818037           46976
# 4                  --           2022         7179119          219617
# 5                  //           2022         4128238           61098
# 6                 NaN           2022         5570873           69531
# 7                 NaN           2022         1917452           42277
# 8                  //           2022         2356101           30349
# 9                   #           2022          491984           13482
#
#                                origin_community  \
# 0                              Sun Microsystems
# 1                                      Netscape
# 2                                     Bell Labs
# 3                Centrum Wiskunde & Informatica
# 4                                           IBM
# 5                                     Bell Labs
# 6  Conseil Européen pour la Recherche Nucléaire
# 7                                           NaN
# 8                                          Zend
# 9                                        Unisys
#
#    central_package_repository_count  file_type  is_open_source
# 0                               NaN       text             NaN
# 1                               NaN       text             NaN
# 2                               0.0       text             NaN
# 3                               NaN       text             NaN
# 4                               0.0       text             NaN
# 5                               0.0       text             NaN
# 6                               0.0       text             NaN
# 7                               0.0       text             NaN
# 8                               NaN       text             NaN
# 9                               NaN       text             NaN
#
# [10 rows x 49 columns]

# %%
df.info() # Gives Data types + non-null counts of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4303 entries, 0 to 4302
# Data columns (total 49 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   pldb_id                            4303 non-null   object
#  1   title                              4303 non-null   object
#  2   description                        823 non-null    object
#  3   type                               4303 non-null   object
#  4   appeared                           4303 non-null   int64
#  5   creators                           1100 non-null   object
#  6   website                            1375 non-null   object
#  7   domain_name                        715 non-null    object
#  8   domain_name_registered             502 non-null    float64
#  9   reference                          1989 non-null   object
#  10  isbndb                             1086 non-null   float64
#  11  book_count                         4303 non-null   int64
#  12  semantic_scholar                   758 non-null    float64
#  13  language_rank                      4303 non-null   int64
#  14  github_repo                        901 non-null    object
#  15  github_repo_stars                  889 non-null    float64
#  16  github_repo_forks                  886 non-null    float64
#  17  github_repo_updated                885 non-null    float64
#  18  github_repo_subscribers            885 non-null    float64
#  19  github_repo_created                878 non-null    float64
#  20  github_repo_description            865 non-null    object
#  21  github_repo_issues                 785 non-null    float64
#  22  github_repo_first_commit           736 non-null    float64
#  23  github_language                    474 non-null    object
#  24  github_language_tm_scope           466 non-null    object
#  25  github_language_type               466 non-null    object
#  26  github_language_ace_mode           465 non-null    object
#  27  github_language_file_extensions    470 non-null    object
#  28  github_language_repos              470 non-null    float64
#  29  wikipedia                          1572 non-null   object
#  30  wikipedia_daily_page_views         1466 non-null   float64
#  31  wikipedia_backlinks_count          1426 non-null   float64
#  32  wikipedia_summary                  1419 non-null   object
#  33  wikipedia_page_id                  1410 non-null   float64
#  34  wikipedia_appeared                 1345 non-null   float64
#  35  wikipedia_created                  1263 non-null   float64
#  36  wikipedia_revision_count           1173 non-null   float64
#  37  wikipedia_related                  1158 non-null   object
#  38  features_has_comments              620 non-null    object
#  39  features_has_semantic_indentation  581 non-null    object
#  40  features_has_line_comments         538 non-null    object
#  41  line_comment_token                 472 non-null    object
#  42  last_activity                      4303 non-null   int64
#  43  number_of_users                    4303 non-null   int64
#  44  number_of_jobs                     4303 non-null   int64
#  45  origin_community                   3113 non-null   object
#  46  central_package_repository_count   2821 non-null   float64
#  47  file_type                          1090 non-null   object
#  48  is_open_source                     511 non-null    object
# dtypes: float64(18), int64(6), object(25)
# memory usage: 1.6+ MB

# %% [markdown]
# ##**3. Exploratory Data Analysis (EDA)**

# %% [markdown]
# ###***Calculating Missing & Duplicate Values***

# %% [markdown]
# We can't drop any columns based on null values because programming languages have been updated and invented quite a lot and most of them have either some or the other missing information, so we work with the missing values.

# %%
# Missing values summary gives columns missing_count and missing_pct

missing = (df.isna().sum()
           .to_frame("missing_count")
           .assign(missing_pct=lambda x: (x["missing_count"] / len(df) * 100).round(2))
           .sort_values("missing_pct", ascending=False))

missing.head(20)  # top 20 columns with most missingness
# Out:
#                                    missing_count  missing_pct
# github_language_ace_mode                    3838        89.19
# github_language_tm_scope                    3837        89.17
# github_language_type                        3837        89.17
# github_language_file_extensions             3833        89.08
# github_language_repos                       3833        89.08
# line_comment_token                          3831        89.03
# github_language                             3829        88.98
# domain_name_registered                      3801        88.33
# is_open_source                              3792        88.12
# features_has_line_comments                  3765        87.50
# features_has_semantic_indentation           3722        86.50
# features_has_comments                       3683        85.59
# domain_name                                 3588        83.38
# github_repo_first_commit                    3567        82.90
# semantic_scholar                            3545        82.38
# github_repo_issues                          3518        81.76
# description                                 3480        80.87
# github_repo_description                     3438        79.90
# github_repo_created                         3425        79.60
# github_repo_updated                         3418        79.43

# %%
# Number of completely duplicated rows
dup_rows = df.duplicated().sum()
print("Duplicate rows:", dup_rows)

# 'pldb_id' is supposed to be unique, hence we are checking duplicates using the feature as well, just to double check
if "pldb_id" in df.columns:
    dup_ids = df["pldb_id"].duplicated().sum()
    print("Duplicate pldb_id values:", dup_ids)
# Out:
# Duplicate rows: 0
# Duplicate pldb_id values: 0

# %% [markdown]
# ###***Type Conversion***

# %%
df_eda = df.copy()

# Converting year-like columns to numeric (coerce invalid values to NaN)
for col in ["appeared", "wikipedia_appeared", "last_activity", "language_rank"]:
    if col in df_eda.columns:
        df_eda[col] = pd.to_numeric(df_eda[col], errors="coerce")

# Converting GitHub numeric columns
github_num_cols = [
    "github_repo_stars", "github_repo_forks", "github_repo_subscribers",
    "github_repo_issues", "github_language_repos",
    "wikipedia_daily_page_views", "wikipedia_backlinks_count", "wikipedia_revision_count",
    "book_count", "central_package_repository_count",
    "number_of_users", "number_of_jobs"
]
for col in github_num_cols:
    if col in df_eda.columns:
        df_eda[col] = pd.to_numeric(df_eda[col], errors="coerce")

# Parsing date columns
date_cols = ["github_repo_updated", "github_repo_created", "github_repo_first_commit", "wikipedia_created"]
for col in date_cols:
    if col in df_eda.columns:
        df_eda[col] = pd.to_datetime(df_eda[col], errors="coerce")

# Converting obvious boolean-like columns
bool_cols = [c for c in df_eda.columns if c.startswith("features_")] + ["is_open_source"]
for col in bool_cols:
    if col in df_eda.columns:
        # Some columns might be True/False already; others may be NaN
        df_eda[col] = df_eda[col].astype("boolean")

df_eda.dtypes.head(10)
# Out:
# pldb_id                    object
# title                      object
# description                object
# type                       object
# appeared                    int64
# creators                   object
# website                    object
# domain_name                object
# domain_name_registered    float64
# reference                  object
# dtype: object

# %% [markdown]
# ###***Numeric Summary Statistics***

# %%
# Basic summary statistics for selected numeric columns, because these are most relevant columns
cols_to_summarize = [
    "appeared", "last_activity", "language_rank",
    "github_repo_stars", "github_repo_forks",
    "wikipedia_daily_page_views",
    "number_of_users", "number_of_jobs",
    "central_package_repository_count"
]
cols_to_summarize = [c for c in cols_to_summarize if c in df_eda.columns]

df_eda[cols_to_summarize].describe().T
# Out:
#                                    count          mean            std     min  \
# appeared                          4303.0   1991.105275     111.443382 -2000.0
# last_activity                     4303.0   2000.616082      84.597760  -900.0
# language_rank                     4303.0   2151.000000    1242.313433     0.0
# github_repo_stars                  889.0   2127.402700    7554.016422     0.0
# github_repo_forks                  886.0    261.286682    1203.002760     0.0
# wikipedia_daily_page_views        1466.0    227.133015     783.552400    -1.0
# number_of_users                   4303.0  13771.264467  227712.946798     0.0
# number_of_jobs                    4303.0    422.183825   12572.985441     0.0
# central_package_repository_count  2821.0      0.000000       0.000000     0.0
#
#                                       25%     50%     75%        max
# appeared                          1984.00  1997.0  2012.0     2023.0
# last_activity                     1992.00  2006.0  2021.0     2023.0
# language_rank                     1075.50  2151.0  3226.5     4302.0
# github_repo_stars                   29.00   194.0  1071.0    88526.0
# github_repo_forks                    2.25    16.0    91.5    23732.0
# wikipedia_daily_page_views           9.00    24.0    99.0    13394.0
# number_of_users                      0.00    20.0   230.0  7179119.0
# number_of_jobs                       0.00     0.0     0.0   771996.0
# central_package_repository_count     0.00     0.0     0.0        0.0

# %% [markdown]
# ###***Plots***

# %% [markdown]
# ####***Plot 1: When languages first appeared (year)***

# %% [markdown]
# ***Dropping rows that appeared before 1544***
#
# This is because the data that we want to drop are making the data skewed and hence they can be considered as outliers

# %%
# Dropping the rows where appeared <= 1544 (including 1544 and earlier)
# Keeping only rows where appeared is NaN OR appeared > 1544
df_eda = df_eda[(df_eda["appeared"].isna()) | (df_eda["appeared"] > 1544)].copy()

# %%
if "appeared" in df_eda.columns:
    series = df_eda["appeared"].dropna().astype(int)
    plt.figure()
    plt.hist(series, bins=40)
    plt.title("Distribution of 'appeared' (year)")
    plt.xlabel("Year appeared")
    plt.ylabel("Count of languages")
    plt.show()

# %% [markdown]
# #### ***Plot 2: GitHub stars (log-scale is helpful because stars are very skewed)***

# %%
if "github_repo_stars" in df_eda.columns:
    stars = df_eda["github_repo_stars"].dropna()
    plt.figure()
    plt.hist(np.log10(stars + 1), bins=40)
    plt.title("GitHub repo stars (log10(stars+1))")
    plt.xlabel("log10(stars + 1)")
    plt.ylabel("Count of languages")
    plt.show()

# %% [markdown]
# ####***Plot 3: Wikipedia daily page views (also skewed)***

# %%
if "wikipedia_daily_page_views" in df_eda.columns:
    # 1) Keep only numeric and non-missing
    views = pd.to_numeric(df_eda["wikipedia_daily_page_views"], errors="coerce").dropna()

    # 2) Remove invalid values for log10(x+1): we need x > -1
    views = views[views > -1]

    # 3) Log transform and keep only finite results (removes -inf/+inf)
    log_views = np.log10(views + 1)
    log_views = log_views[np.isfinite(log_views)]

    plt.figure()
    plt.hist(log_views, bins=40)
    plt.title("Wikipedia daily page views (log10(views+1))")
    plt.xlabel("log10(views + 1)")
    plt.ylabel("Count of languages")
    plt.show()

    print("Dropped invalid/NaN views:", len(df_eda) - len(views))
# Out:
# Dropped invalid/NaN views: 2889

# %% [markdown]
# ####***Plot 4: Top language types***

# %%
if "type" in df_eda.columns:
    counts = df_eda["type"].value_counts().head(15)
    plt.figure()
    plt.bar(counts.index.astype(str), counts.values)
    plt.title("Top 15 values of 'type'")
    plt.xlabel("type")
    plt.ylabel("Count")
    plt.xticks(rotation=45, ha="right")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ####***Plot 5: Relationship Jobs vs Users***

# %% [markdown]
# X-axis (number_of_users) is on the scale 10^6 and hence, There are two outliers HTTP (jobs=771996, users=33780) and SQL (jobs=219617, users=7179119)

# %%
# Scatter: number_of_users vs number_of_jobs
if set(["number_of_users", "number_of_jobs"]).issubset(df_eda.columns):
    tmp = df_eda[["number_of_users", "number_of_jobs"]].dropna()
    plt.figure()
    plt.scatter(tmp["number_of_users"], tmp["number_of_jobs"], s=10)
    plt.title("Jobs vs Users")
    plt.xlabel("number_of_users")
    plt.ylabel("number_of_jobs")
    plt.show()

# %% [markdown]
# ####***Plot 6: Relationship GitHub stars vs Wikipedia views***

# %%
# Scatter (log scale): GitHub stars vs Wikipedia views
if set(["github_repo_stars", "wikipedia_daily_page_views"]).issubset(df_eda.columns):
    tmp = df_eda[["github_repo_stars", "wikipedia_daily_page_views", "title"]].dropna()
    x = np.log10(tmp["github_repo_stars"] + 1)
    y = np.log10(tmp["wikipedia_daily_page_views"] + 1)

    plt.figure()
    plt.scatter(x, y, s=10)
    plt.title("GitHub stars vs Wikipedia views (log-log)")
    plt.xlabel("log10(github_repo_stars + 1)")
    plt.ylabel("log10(wikipedia_daily_page_views + 1)")
    plt.show()

    # Show the top 10 by stars to connect points to real languages
    top10 = tmp.sort_values("github_repo_stars", ascending=False).head(10)[["title", "github_repo_stars", "wikipedia_daily_page_views"]]
    top10
# Out:
# /usr/local/lib/python3.12/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ### ***Correlations***

# %%
# Correlation matrix for a small set of numeric columns
num_cols = [
    "github_repo_stars", "github_repo_forks", "github_repo_subscribers",
    "wikipedia_daily_page_views", "wikipedia_backlinks_count",
    "number_of_users", "number_of_jobs"
]
num_cols = [c for c in num_cols if c in df_eda.columns]
corr = df_eda[num_cols].corr(numeric_only=True)
corr
# Out:
#                             github_repo_stars  github_repo_forks  \
# github_repo_stars                    1.000000           0.842264
# github_repo_forks                    0.842264           1.000000
# github_repo_subscribers              0.892564           0.928575
# wikipedia_daily_page_views           0.589823           0.494591
# wikipedia_backlinks_count            0.283119           0.321279
# number_of_users                      0.375530           0.439711
# number_of_jobs                       0.293965           0.406260
#
#                             github_repo_subscribers  \
# github_repo_stars                          0.892564
# github_repo_forks                          0.928575
# github_repo_subscribers                    1.000000
# wikipedia_daily_page_views                 0.644099
# wikipedia_backlinks_count                  0.370503
# number_of_users                            0.474368
# number_of_jobs                             0.428320
#
#                             wikipedia_daily_page_views  \
# github_repo_stars                             0.589823
# github_repo_forks                             0.494591
# github_repo_subscribers                       0.644099
# wikipedia_daily_page_views                    1.000000
# wikipedia_backlinks_count                     0.413102
# number_of_users                               0.453071
# number_of_jobs                                0.342182
#
#                             wikipedia_backlinks_count  number_of_users  \
# github_repo_stars                            0.283119         0.375530
# github_repo_forks                            0.321279         0.439711
# github_repo_subscribers                      0.370503         0.474368
# wikipedia_daily_page_views                   0.413102         0.453071
# wikipedia_backlinks_count                    1.000000         0.431046
# number_of_users                              0.431046         1.000000
# number_of_jobs                               0.147825         0.324025
#
#                             number_of_jobs
# github_repo_stars                 0.293965
# github_repo_forks                 0.406260
# github_repo_subscribers           0.428320
# wikipedia_daily_page_views        0.342182
# wikipedia_backlinks_count         0.147825
# number_of_users                   0.324025
# number_of_jobs                    1.000000

# %% [markdown]
# #### ***Correlations Pairplot***

# %%
# Make a copy with only these columns, numeric-safe
pair_df = df_eda[num_cols].apply(pd.to_numeric, errors="coerce").copy()

# Add log columns (recommended because these are very skewed)
for c in num_cols:
    # log10(x+1) requires x >= 0, so set negatives to NaN
    safe = pair_df[c].where(pair_df[c] >= 0, np.nan)
    pair_df[f"log_{c}"] = np.log10(safe + 1)

# Choose what you want to plot:
# Option A: plot the log columns only (usually best)
plot_cols = [f"log_{c}" for c in num_cols]

# Drop rows with missing values in the plotted columns
plot_df = pair_df[plot_cols].dropna()

sns.pairplot(
    plot_df,
    diag_kind="hist",
    plot_kws={"s": 12, "alpha": 0.35}
)
plt.suptitle("Pairplot of log10(x+1) versions", y=1.02)
plt.show()

# %% [markdown]
# ###***Text EDA***

# %%
# Select the three columns that have strig values
text_cols = [c for c in ["description", "wikipedia_summary", "github_repo_description"] if c in df_eda.columns]

# For each column we select -> drop missing -> check if the content is all string -> get the length of the string
for col in text_cols:
    lengths = df_eda[col].dropna().astype(str).str.len()
    # we get the number of non-null rows, avg no of characters (mean_length), middle length (median_length)
    print(f"{col}: non-null={lengths.shape[0]}, mean_len={lengths.mean():.1f}, median_len={lengths.median():.1f}\n")
# Out:
# description: non-null=820, mean_len=238.9, median_len=165.0
#
# wikipedia_summary: non-null=1415, mean_len=837.9, median_len=672.0
#
# github_repo_description: non-null=865, mean_len=60.5, median_len=49.0

# %% [markdown]
# ####***Plot for Text Comparison***

# %%
# Get character lengths (drop missing)
ws_len   = df_eda["wikipedia_summary"].astype("string").str.len().dropna()
desc_len = df_eda["description"].astype("string").str.len().dropna()
gh_len   = df_eda["github_repo_description"].astype("string").str.len().dropna()

bins = 40  # adjust if you want more/less detail

plt.figure()
plt.hist(ws_len,   bins=bins, alpha=0.5, label="wikipedia_summary")
plt.hist(desc_len, bins=bins, alpha=0.5, label="description")
plt.hist(gh_len,   bins=bins, alpha=0.5, label="github_repo_description")

plt.title("Text length distributions (characters)")
plt.xlabel("Characters")
plt.ylabel("Count of rows")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ##**4. Insights**

# %% [markdown]
# After analyzing the `languages.csv` dataset, we uncovered five insights that challenge the typical narrative of "popular" programming. Here is what the data actually says about the history and state of code.
#
# ### **1. The "Job Market" Plot Twist: Protocols Over Syntax**
#
# **The Finding:** If you look for the skill with the most job openings, you won't find Java or Python at the top. The winner is **HTTP** (771,996 jobs), followed by **SQL**.<br><br>
# **The Takeaway:** This was a massive surprise. It reminds us that our dataset defines "language" broadly. More importantly, it signals that companies are desperate for engineers who understand the *infrastructure* of the web (how data moves) even more than they value knowledge of a specific syntax. "Knowing how the internet works" is the ultimate employability hack.<br><br>
#
# ### **2. The Unsung Architect: Niklaus Wirth**
#
# **The Finding:** While names like James Gosling (Java) and Guido van Rossum (Python) dominate the headlines, the most prolific creator in this dataset is **Niklaus Wirth**. He is credited with **8 different languages**, including influential heavyweights like Pascal, Modula-2, and Oberon.<br><br>
# **The Takeaway:** We often view languages as "one-hit wonders" defined by a single creator. Wirth’s presence shows that language design can be a career-long discipline. He didn't just write code; he shaped the structural philosophy of programming for decades.<br><br>
#
# ### **3. A 4,000-Year Timeline**
#
# **The Finding:** This isn't just a history of computers; it's a history of logic. The dataset spans over **4,000 years**, stretching from **Babylonian Numerals (~2000 BC)** all the way to modern languages created in 2023 (like TQL).<br><br>
# **The Takeaway:** It is fascinating that the dataset treats mathematical notations (like Binary and Balanced Ternary) as ancestors to modern code. It blurs the line between "counting" and "coding," proving that humans were developing algorithms on clay tablets long before we put them on silicon.<br><br>
#
# ### **4. SQL is the "Lingua Franca"**
#
# **The Finding:** Despite the immense hype around Python and JavaScript, **SQL** holds the crown for the highest number of users (about 7.1 million). It significantly outperforms JavaScript (about 5.9M) and Java (about 5.5M).<br><br>
# **The Takeaway:** SQL is the quiet giant of the tech world. While developers fight over which backend language is best, almost all of them agree on one thing: they need to talk to a database. SQL isn't just a language; it’s a universal secondary skill required for virtually every data and development role.<br><br>
#
# ### **5. The "Long Tail" of Specialization**
#
# **The Finding:** While 78% of the dataset is made up of standard "Programming Languages" (pl), there is a thriving ecosystem of specialized tools: **97 text markups**, **94 query languages**, and **69 XML formats**.<br><br>
# **The Takeaway:** We tend to think of coding as just writing logic loops. However, the sheer volume of "query languages" highlights how specialized the industry has become. It’s no longer just about *creating* data; a huge portion of the language ecosystem is dedicated solely to *retrieving* and *structuring* it.

# %% [markdown]
# ###***Few More Key Findings (includes new tables and plots)***

# %% [markdown]
# ####***What are the top 10 programming languages that have the most number of jobs?***

# %%
# Top 10 Languages by Jobs
print("Top 10 by Jobs:\n", df_eda[['title', 'number_of_jobs']].nlargest(10, 'number_of_jobs'))
# Out:
# Top 10 by Jobs:
#           title  number_of_jobs
# 38        HTTP          771996
# 4          SQL          219617
# 0         Java           85206
# 6         HTML           69531
# 1   JavaScript           63993
# 5          C++           61098
# 2            C           59919
# 13       MySQL           47466
# 3       Python           46976
# 15         CSS           45617

# %% [markdown]
# ####***What are the top 10 programming languages that have the most number of users?***

# %%
# Top 10 by Users
print("\nTop 10 by Users:\n", df_eda[['title', 'number_of_users']].nlargest(10, 'number_of_users'))
# Out:
# Top 10 by Users:
#           title  number_of_users
# 4          SQL          7179119
# 1   JavaScript          5962666
# 6         HTML          5570873
# 0         Java          5550123
# 5          C++          4128238
# 2            C          3793768
# 15         CSS          2881846
# 3       Python          2818037
# 10      MATLAB          2661579
# 13       MySQL          2608362

# %% [markdown]
# ####***Who invented the programming language?***

# %% [markdown]
# After the EDA one interesting fact that we analysed was that the programming languages are developed by individuals and not organisations, and Niklaus Wirth has created the most number of languages.

# %%
# Split the comma-separated creators and count them
creators_series = df_eda['creators'].dropna().str.split(',').explode().str.strip()
top_creators = creators_series.value_counts().head(10)

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x=top_creators.values, y=top_creators.index)
plt.title('Top 10 Most Prolific Language Creators')
plt.xlabel('Number of Languages Created')
plt.show()

# %% [markdown]
# ####***Who owns the Programming Language?***

# %% [markdown]
# Through the EDA phase we conluded that most (88.6%) of the programming languages are open sourced while still a significant number (11.4%) of languages are Proprietary Languages

# %%
if 'is_open_source' in df_eda.columns:
    plt.figure(figsize=(6, 6))
    df_eda['is_open_source'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
    plt.title('Is the language Open Source?')
    plt.ylabel('')
    plt.show()

# %% [markdown]
# ##**Question 2: Market Archetypes**

# %% [markdown]
# Can we segment programming languages into distinct "Market Archetypes": specifically "Hype Driven" (high GitHub stars, low job counts) vs. "Silent Giants" (low social hype, high job counts and user estimates)

# %%
features=['github_repo_stars','number_of_jobs','number_of_users','wikipedia_daily_page_views']

# %%
#cleaning the data by making the negative values as 0 and handling the missing values

for feature in features:
    df_eda[feature] = pd.to_numeric(df_eda[feature], errors='coerce')
df_subset = df_eda[features].fillna(0)

# Ensure no negative values remain in df_subset before log transformation.
# The 'wikipedia_daily_page_views' column has a minimum value of -1.0 in the original data,
# which would lead to log10(0) and thus -inf after adding 1.
df_subset[df_subset < 0] = 0

#to handle the long tail skewness
df_log = np.log10(df_subset+1)

#standardizing for Cluster
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_log)

# %%
#K-Means Clustering
from sklearn.cluster import KMeans

#using k=4
kmeans=KMeans(n_clusters=4,random_state=42,n_init=10)
df_eda['cluster']=kmeans.fit_predict(df_scaled)

# Visualize the archetypes
plt.figure(figsize=(12,7))
scatter=sns.scatterplot(
    x=df_log['github_repo_stars'],
    y=df_log['number_of_jobs'],
    hue = df_eda['cluster'],
    alpha=0.6,
    s=60)

plt.title('Market Archetypes: K-Means Clustering')
plt.xlabel('GitHub Stars')
plt.ylabel('Number of Jobs')
plt.show()
plt.grid(True, linestyle="--", alpha=0.5)

#For Clustering
print("Cluster Profiles (Mean values):")
# Select only the numeric columns relevant for profiling before calculating the mean
# Using the 'features' list defined earlier, which contains the numeric columns for clustering
print(df_eda.groupby('cluster')[features].mean())

#identify representative examples for each cluster
for i in range(4):
    print(f"\nRepresentative Examples for Cluster {i}:")
    print(df_eda[df_eda['cluster'] == i].sort_values(by='number_of_jobs', ascending=False).head(4))
# Out:
# Cluster Profiles (Mean values):
#          github_repo_stars  number_of_jobs  number_of_users  \
# cluster
# 0                17.384615        0.174724      1086.404580
# 1                 8.585106        0.000000         8.426389
# 2             38310.615385    22151.573171    683414.829268
# 3              2061.308148        0.032593      2824.760000
#
#          wikipedia_daily_page_views
# cluster
# 0                        159.525641
# 1                          1.048951
# 2                       1750.775000
# 3                         59.391304
#
# Representative Examples for Cluster 0:
#          pldb_id        title description             type  appeared  \
# 96          rexx         Rexx         NaN               pl      1979
# 100        antlr        ANTLR         NaN  grammarLanguage      1992
# 73   common-lisp  Common Lisp         NaN               pl      1984
# 124       llvmir      LLVM IR         NaN               ir      2003
#
#                                               creators  \
# 96                                      Mike Cowlishaw
# 100                                                NaN
# 73   Scott Fahlman and Richard P. Gabriel and David...
# 124                                                NaN
#
#                                website      domain_name  \
# 96                                 NaN              NaN
# 100               http://www.antlr.org        antlr.org
# 73             http://common-lisp.net/  common-lisp.net
# 124  http://llvm.org/docs/LangRef.html              NaN
#
#      domain_name_registered reference  ...  features_has_line_comments  \
# 96                      NaN       NaN  ...                       False
# 100                  1997.0       NaN  ...                        True
# 73                   2003.0       NaN  ...                        True
# 124                     NaN       NaN  ...                        True
#
#      line_comment_token  last_activity  number_of_users number_of_jobs  \
# 96                  NaN           2022              435             40
# 100                  //           2022             3048             30
# 73                    ;           2022             1891             24
# 124                   ;           2018             5812             23
#
#                           origin_community  central_package_repository_count  \
# 96                                     IBM                               0.0
# 100            University of San Francisco                               0.0
# 73   American National Standards Institute                               0.0
# 124                https://github.com/llvm                               0.0
#
#     file_type  is_open_source cluster
# 96       text            <NA>       0
# 100      text            True       0
# 73       text            <NA>       0
# 124      text            True       0
#
# [4 rows x 50 columns]
#
# Representative Examples for Cluster 1:
#       pldb_id             title  \
# 4302      xql               XQL
# 238       muf  Multi-User Forth
# 323   speedie           Speedie
# 387       ion               Ion
#
#                                             description           type  \
# 4302  XQL is a query language designed specifically ...  queryLanguage
# 238                                                 NaN             pl
# 323   "General-purpose modern and clean object-orien...             pl
# 387   Amazon Ion is a richly-typed, self-describing,...            idl
#
#       appeared          creators                               website  \
# 4302      1999    Jonathan Robie                                   NaN
# 238       1995               NaN                                   NaN
# 323       2022  Theodore H Smith  http://github.com/gamblevore/speedie
# 387       2016               NaN                                   NaN
#
#       domain_name  domain_name_registered  \
# 4302          NaN                     NaN
# 238           NaN                     NaN
# 323   speedie.dev                  2023.0
# 387           NaN                     NaN
#
#                                          reference  ...  \
# 4302  http://www.ibiblio.org/xql/xql-tutorial.html  ...
# 238                                            NaN  ...
# 323                                            NaN  ...
# 387               https://amzn.github.io/ion-docs/  ...
#
#       features_has_line_comments  line_comment_token  last_activity  \
# 4302                        <NA>                 NaN           1999
# 238                         <NA>                 NaN           2004
# 323                         <NA>                  //           2023
# 387                         True                  //           2016
#
#       number_of_users number_of_jobs                    origin_community  \
# 4302                0              0                                 NaN
# 238                30              0  University of California, Berkeley
# 323                 1              0                                 NaN
# 387                 0              0                     Amazon.com, Inc
#
#       central_package_repository_count file_type  is_open_source cluster
# 4302                               NaN       NaN            <NA>       1
# 238                                0.0      text            <NA>       1
# 323                                NaN      text            <NA>       1
# 387                                NaN       NaN            <NA>       1
#
# [4 rows x 50 columns]
#
# Representative Examples for Cluster 2:
#    pldb_id title description           type  appeared  \
# 38    http  HTTP         NaN       protocol      1989
# 4      sql   SQL         NaN  queryLanguage      1974
# 0     java  Java         NaN             pl      1995
# 6     html  HTML         NaN     textMarkup      1991
#
#                                      creators                   website  \
# 38                                        NaN                       NaN
# 4   Donald D. Chamberlin and Raymond F. Boyce                       NaN
# 0                               James Gosling  https://oracle.com/java/
# 6                             Tim Berners-Lee                       NaN
#
#    domain_name  domain_name_registered reference  ...  \
# 38         NaN                     NaN       NaN  ...
# 4          NaN                     NaN       NaN  ...
# 0          NaN                     NaN       NaN  ...
# 6          NaN                     NaN       NaN  ...
#
#     features_has_line_comments  line_comment_token  last_activity  \
# 38                        <NA>                 NaN           2022
# 4                         True                  --           2022
# 0                         True                  //           2022
# 6                        False                 NaN           2022
#
#     number_of_users number_of_jobs  \
# 38            33780         771996
# 4           7179119         219617
# 0           5550123          85206
# 6           5570873          69531
#
#                                 origin_community  \
# 38                 The World Wide Web Consortium
# 4                                            IBM
# 0                               Sun Microsystems
# 6   Conseil Européen pour la Recherche Nucléaire
#
#     central_package_repository_count file_type  is_open_source cluster
# 38                               0.0        na            <NA>       2
# 4                                0.0      text            <NA>       2
# 0                                NaN      text            <NA>       2
# 6                                0.0      text            <NA>       2
#
# [4 rows x 50 columns]
#
# Representative Examples for Cluster 3:
#      pldb_id        title                                        description  \
# 672  rholang      Rholang  Rholang is an open and scalable blockchain lan...
# 115     wasm  WebAssembly                                                NaN
# 113     haxe         Haxe                                                NaN
# 117   chapel       Chapel                                                NaN
#
#                  type  appeared  \
# 672  contractLanguage      2016
# 115          bytecode      2015
# 113                pl      2005
# 117                pl      2004
#
#                                               creators  \
# 672                                                NaN
# 115                                         Alon Zakai
# 113                                   Nicolas Cannasse
# 117  David Callahan and Hans Zima and Brad Chamberl...
#
#                                  website                 domain_name  \
# 672  https://rchain-community.github.io/  rchain-community.github.io
# 115              http://webassembly.org/             webassembly.org
# 113                      http://haxe.org                    haxe.org
# 117             https://chapel-lang.org/             chapel-lang.org
#
#      domain_name_registered                                     reference  \
# 672                     NaN                                           NaN
# 115                  2015.0                                           NaN
# 113                  2005.0                                           NaN
# 117                  2014.0  https://ieeexplore.ieee.org/document/1299190
#
#      ...  features_has_line_comments  line_comment_token  last_activity  \
# 672  ...                        <NA>                 NaN           2023
# 115  ...                        True                 NaN           2022
# 113  ...                        True                  //           2022
# 117  ...                        True                  //           2022
#
#      number_of_users number_of_jobs                     origin_community  \
# 672             2325             13  https://rchain-community.github.io/
# 115             8291              5                                  W3C
# 113             8831              1                      Haxe Foundation
# 117            16150              1                                 Cray
#
#      central_package_repository_count file_type  is_open_source cluster
# 672                               NaN       NaN            True       3
# 115                               0.0      text            True       3
# 113                               NaN      text            True       3
# 117                               0.0      text            True       3
#
# [4 rows x 50 columns]
