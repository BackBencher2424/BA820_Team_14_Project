# %% [markdown]
# <a href="https://colab.research.google.com/github/BackBencher2424/BA820_Team_14_Project/blob/main/BA820_Team_14_Project_Proposal_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Project Title:** *Code Trends, Quantified: Mapping the Programming Language Ecosystem*<br>
# ***Section & Team:** B1 Team 14* <br>
# ***Team Members:** Drishti Chulani, Arshdeep Singh Oberoi, Ahrar Karim, Vishesh Goyal* <br>

# %% [markdown]
# ##**1. Primary Dataset**

# %% [markdown]
# ###**1.1. Project Motivation and Preliminary Exploratory Data Analysis (EDA)**

# %% [markdown]
# ####***Project Motivation***

# %% [markdown]
# <p align = "justify">As MS Business Analytics students with deep roots in technology, we are constantly navigating the global "fuss" and intense hype surrounding the world of coding. While we rely on Python as our primary tool for solving complex analytical problems, we realized we were only seeing a small fraction of a much vaster landscape. This project was born from a desire to look under the hood of that hype, using our data expertise to perform a comprehensive census of the programming paradigm and understand the thousands of languages that have shaped human logic.</p>
#
# <p align = "justify">Our goal is to quantify this ecosystem by exploring the sheer scale of languages in existence—from ancient numeral systems to the latest 2023 releases. By analyzing key metrics like job demand and user populations, we aim to identify which languages are the true titans of industry and which are emerging as the next big thing. Ultimately, we want to transform the noise surrounding "learning to code" into a clear, data-driven map that shows where the tech world has been and where it is heading.</p>
# <p align = "justify">Major stakeholders would be Chief Technology Offiers(CTOs), Product Managers, School Educators, Mentors and Students.</p>

# %% [markdown]
# ####***Preliminary Exploratory Data Analysis (EDA)***

# %% [markdown]
# After analyzing the `languages.csv` dataset, we uncovered five insights that challenge the typical narrative of "popular" programming. Here is what the data actually says about the history and state of code.
#
# ##### **1. The "Job Market" Plot Twist: Protocols Over Syntax**
#
# **The Finding:** If you look for the skill with the most job openings, you won't find Java or Python at the top. The winner is **HTTP** (771,996 jobs), followed by **SQL**.<br><br>
# **The Takeaway:** This was a massive surprise. It reminds us that our dataset defines "language" broadly. More importantly, it signals that companies are desperate for engineers who understand the *infrastructure* of the web (how data moves) even more than they value knowledge of a specific syntax. "Knowing how the internet works" is the ultimate employability hack.<br><br>
#
# ##### **2. The Unsung Architect: Niklaus Wirth**
#
# **The Finding:** While names like James Gosling (Java) and Guido van Rossum (Python) dominate the headlines, the most prolific creator in this dataset is **Niklaus Wirth**. He is credited with **8 different languages**, including influential heavyweights like Pascal, Modula-2, and Oberon.<br><br>
# **The Takeaway:** We often view languages as "one-hit wonders" defined by a single creator. Wirth’s presence shows that language design can be a career-long discipline. He didn't just write code; he shaped the structural philosophy of programming for decades.<br><br>
#
# ##### **3. A 4,000-Year Timeline**
#
# **The Finding:** This isn't just a history of computers; it's a history of logic. The dataset spans over **4,000 years**, stretching from **Babylonian Numerals (~2000 BC)** all the way to modern languages created in 2023 (like TQL).<br><br>
# **The Takeaway:** It is fascinating that the dataset treats mathematical notations (like Binary and Balanced Ternary) as ancestors to modern code. It blurs the line between "counting" and "coding," proving that humans were developing algorithms on clay tablets long before we put them on silicon.<br><br>
#
# ##### **4. SQL is the "Lingua Franca"**
#
# **The Finding:** Despite the immense hype around Python and JavaScript, **SQL** holds the crown for the highest number of users (about 7.1 million). It significantly outperforms JavaScript (about 5.9M) and Java (about 5.5M).<br><br>
# **The Takeaway:** SQL is the quiet giant of the tech world. While developers fight over which backend language is best, almost all of them agree on one thing: they need to talk to a database. SQL isn't just a language; it’s a universal secondary skill required for virtually every data and development role.<br><br>
#
# ##### **5. The "Long Tail" of Specialization**
#
# **The Finding:** While 78% of the dataset is made up of standard "Programming Languages" (pl), there is a thriving ecosystem of specialized tools: **97 text markups**, **94 query languages**, and **69 XML formats**.<br><br>
# **The Takeaway:** We tend to think of coding as just writing logic loops. However, the sheer volume of "query languages" highlights how specialized the industry has become. It’s no longer just about *creating* data; a huge portion of the language ecosystem is dedicated solely to *retrieving* and *structuring* it.

# %% [markdown]
# ###**1.2.  Domain / Business Questions (Core Section)**

# %% [markdown]
# ####**Question 1: Do programming languages naturally cluster into distinct groups based on shared technical features (syntax patterns, file types) and community signals (GitHub activity, Wikipedia view)?**

# %% [markdown]
# **Motivation**: <p align='justify'> Our EDA showed Github_repo_stars being extremely skewed. While most analysts focus on the "Top 10," there is a massive Long Tail of thousands of languages. I want to see if these overlooked languages actually form groups that share the features of successful ones.<br><br></p>
#
# **Why It Matters**: <p align='justify'> If a college is building a bootcamp or learning platform curriculum, identifying these hidden language families could open up niche markets. Instead of competing head-to-head in saturated spaces like Python and Java, targeted programs around clusters of related languages that share learning curves and community needs could be developed.<br><br></p>
#
# **The Surprising Part**: <p align='justify'> It would be interesting if older languages (pre-1980) ended up in the same clusters as modern web languages, purely based on their GitHub engagement patterns. That would suggest community adoption dynamics matter more than when a language was actually created.</p>

# %% [markdown]
# ####**Question 2: Can we segment programming languages into distinct "Market Archetypes": specifically "Hype Driven" (high GitHub stars/subscribers, low job counts) vs. "Silent" (low social hype, high job counts and user estimates)?**

# %% [markdown]
# **Motivation:** <p align="justify"> In the scatter plot, some languages dominate the conversation on GitHub for being popular, while others,are actually running production systems and paying people's salaries. This suggests that popularity is not directly correlated to employment.<br><br></p>
#
# **Why It Matters:** <p align = "justify"> This can act as a risk-assessment tool for CTOs and curriculum leads for separating whats trendy and whats actually in use and show up in job markets with less competition. That's valuable for schools trying to prepare students for real employment rather than just what looks good on a resume.<br><br></p>
#
# **The Surprising Part:** <p align = "justify"> It would be striking if corporate-backed languages from tech famous languages frequently fell into the "Hype-Driven" cluster, suggesting that massive company branding generates more social "noise" than actual industrial deployment compared to grassroots languages.<br><br></p>

# %% [markdown]
# ####**The Question 3: Can we detect "Ghost Languages" technologies with significant cultural visibility (high Wikipedia views and rankings) but virtually no real employment ecosystem?**

# %% [markdown]
# **Motivation:** <p align="justify">Our data shows the median job count is zero, yet language rankings vary dramatically, which is very weird. There's a whole category of languages that look important on paper—they're ranked, they're discussed—but there's no actual work there. That statistical anomaly is worth understanding.<br><br></p>
#
# **Decision Impact:** <p align="justify">This becomes a practical filter for career counselors. They can spot "Famous-in-Theory" languages that have zero actual job market, protecting students from spending months learning something that won't lead anywhere. It's the difference between being known and being useful.<br><br></p>
#
# **The Surprising Part:** <p align="justify">Discovering a language in the top 10% globally for Wikipedia visibility that has no recorded jobs and no active development community—a technology that's somehow academically prominent but completely economically dormant.<br><br></p>

# %% [markdown]
# ####**The Question 4: Among the 49 technical metadata features we have (syntax patterns, file types, naming conventions), which ones actually predict how long a language survives and remains relevant in the long run?**

# %% [markdown]
# **Motivation:** <p align="justify">While working with 49 columns, many of them are correlated or sparse and there's a lot of noise to cut through. This brought out the question: what's the minimal set of technical characteristics that actually matter for a language's staying power?<br><br></p>
#
# **Decision Impact:** <p align="justify">This allows Programming Language designers to understand which technical specs (e.g., case sensitivity or comment styles) are most associated with surviving the first 10 years of a language's life.<br><br></p>
#
# **The Surprise:** <p align="justify">If "Metadata Completeness" (having a domain registered or a Wikipedia page) turns out to explain more about a language's success than the actual technical syntax features do. This would mean that community documentation matters more than the design<br><br></p>

# %% [markdown]
# ##**2. Backup Dataset**

# %% [markdown]
# ###**2.1. Project Motivation and Preliminary Exploratory Data Analysis (EDA)**

# %% [markdown]
# ####***Project Motivation***

# %% [markdown]
# <p align ="justify"> Bob Ross's "The Joy of Painting" is an unusual phenomenon in terms of the confluence of art, education, and visual consistency on a large scale. Over the course of numerous episodes, Bob Ross created paintings that, while visually consistent in terms of style at first glance, show interesting variation in terms of the use of colors, composition, and the scenes depicted. Determining the underlying patterns of variation in terms of latent styles, compositions, or temporal evolution is not only important from an artistic perspective but also from the perspective of content organization and decision-making.<br><br></p>
#
# <p align ="justify">The dataset used in this project, which represents paintings in terms of structured indicators for the use of colors, the presence of landscape, and the ordering of the episodes, creates an unusual opportunity for the analysis of artistic patterns on a large scale. Unlike traditional approaches to analyzing images, this dataset represents paintings in terms of abstract, understandable concepts, which makes it possible to analyze the patterns in terms of style, composition, and variation in an understandable manner.<br><br></p>
#
# <p align ="justify">From a business and organizational point of view, finding the latent structure within this data can be used to organize the visual content in terms of categorization, recommendation, and even repurposing. For instance, finding the visual styles or templates within the images can be used for content recommendation systems, art education platform curricula, and even thematic curation for streaming or media archives. Since the data set doesn’t offer any labels for the styles or categories, an unsupervised method can be used effectively to find the hidden patterns within the data.</p>

# %% [markdown]
# ####***Preliminary Exploratory Data Analysis (EDA)***

# %% [markdown]
# <p align ="justify">The initial EDA revealed the following about the distribution, variation, and interrelation of the color usage, landscape elements, and temporal order of the paintings:<br></p>
#
# #####**Color Usage**
#
# <p align ="justify">The analysis of the binary variables representing the colors indicates that the number of colors used varies substantially between paintings. The derived variable num_colors shows that the distribution is skewed, with some paintings using a small number of colors, while others use a much richer set of colors. A small number of colors is found in most paintings, but most colors tend to be used in combination with other colors, suggesting that color usage may be an important factor in differentiating between visual styles.<br><br></p>
#
# #####**Landscape Elements**
#
# <p align ="justify">The landscape element variables also show uneven usage, with some elements, such as trees, mountains, or water-related elements, being very common, and others, such as cabins or man-made objects, being less common. More importantly, the EDA reveals that the elements tend to co-occur, suggesting that some elements may be part of a composition template or "bundle" that is repeated in different paintings. Furthermore, the total number of elements used in each painting varies substantially, suggesting that the composition of some paintings may be more complex than others.<br><br></p>
#
# #####**Composition Structure**
#
# <p align ="justify">EDA’s aggregation of element indicators at the row level helps identify significant variations in composition density, where some compositions have few elements, while others have many. This is observed across the entire dataset rather than just a few episodes, suggesting that the simplicity or complexity of composition might be a matter of style rather than limitation.<br><br></p>
#
# #####**Temporal Patterns**
#
# <p align ="justify">EDA employed the created variable ‘chronological_order’ to analyze the evolution of the paintings over the course of the series. Although the elements and colors used remain relatively consistent, their combinations and emphasis change. Notably, there is no monotonic trend in palette size and contrast usage across seasons, implying that style evolves throughout the series rather than in a linear fashion.</p>

# %% [markdown]
# ###**2.2.  Domain / Business Questions (Core Section)**

# %% [markdown]
# ####**Question 1: Do Bob Ross paintings exhibit latent “visual styles” driven more by color palette structure than by the specific landscape elements depicted?**

# %% [markdown]
# #####***What result would be surprising***
#
# It would be surprising if the variation in the structure of the color palette, for instance, the number of colors used and the combinations of colors, did not provide significant additional differentiation beyond the landscape features, especially considering the high variance in the distribution of num_colors and the co-occurrence of colors in the EDA. In particular, if paintings with very different combinations of colors are grouped together mainly based on similarities in landscape features, then this goes against the strong role that color seems to play in the definition of style.

# %% [markdown]
# #####***Why this question is worth answering***
#
# This question seeks to determine if the style of paintings in the dataset is influenced more by the color of the scenes than by the depiction of elements. The dataset is particularly well-suited to answer this question because it has rich binary information on both colors and elements, as well as a quantitative measure of color palette size (num_colors).

# %% [markdown]
# ####**Question 2 : Do paintings at different points in the chronological order of the series differ more in composition structure than in subject matter?**

# %% [markdown]
# #####***What outcome would be surprising***
#
# It would be surprising if there were no differences between paintings early and late in the chronological order of the series in terms of composition structure, such as the total number of elements and combinations of elements, considering the wide range of composition density variations found across paintings in EDA.

# %% [markdown]
# #####***Why this question is worth answering***
#
# In addition, the data set includes a derived variable named chronological_order, along with detailed binary indicators of the landscape, which enables the differentiation between changes in the subject matter and changes in the structural composition.

# %% [markdown]
# ####**Question 3: Are there distinct painting clusters defined by contrast intensity (light vs dark color mixes), independent of season order?**

# %% [markdown]
# #####***What would be surprising***
#
# It would be unexpected if paintings that are grouped according to the intensity of contrast, as indicated by the relative use of light and dark color indicators, also tended to fall in seasonal order, suggesting that contrast varied monotonically over time rather than being a stylistic device.

# %% [markdown]
# #####***Why this question is worth answering***
#
# From the EDA, it is observed that the combination of light and dark colors varies considerably in the paintings, and no monotonic trend is observed. This indicates that the intensity of contrast might be used as a recurring stylistic element.

# %% [markdown]
# ####**Question 4: Are there recurring “element bundles” that appear together far more often than expected given their individual frequencies?**

# %% [markdown]
# #####***What outcome would be surprising***
#
# It would be surprising if the co-occurrence of the landscape element was mostly random with little or no stable bundles emerging, given the high individual element frequencies and co-occurrence patterns observed in the EDA.

# %% [markdown]
# #####***Why this question is worth answering***
#
# The binary nature of the element data enables direct analysis of co-occurrence patterns across hundreds of images. Identifying stable bundles of elements could reveal the use of reusable compositional templates, which is useful in scalable content categorization, recommendation, and instruction.

# %% [markdown]
# ##**3. Appendix**

# %% [markdown]
# ###**GitHub Repository**

# %% [markdown]
# ***Link to Github Repo:** [Github Repo Link](https://github.com/BackBencher2424/BA820_Team_14_Project)*

# %% [markdown]
# ###**Other Important Links**

# %% [markdown]
# ***Link to Colab Notebook (EDA Primary Dataset):** [Primary Dataset EDA Notebook](https://colab.research.google.com/drive/1KR8Z4ZS2_CrUe3nTaPI5AWtBwOZ6QDQn?usp=sharing)* <br>
#
# ***Link to Colab Notebook (EDA Backup Dataset):** [Backup Dataset EDA Notebook](https://colab.research.google.com/drive/1hv-sx-c6sdlDacv2ooOj7u4S3TcMz_Yb?usp=sharing)* <br>
#
# ***Primary Dataset:** [Programming Languages Dataset Link](https://github.com/rfordatascience/tidytuesday/tree/main/data/2023/2023-03-21)*<br>
#
# ***Backup Dataset:** [Bob Ross Paintings Dataset Link](https://github.com/rfordatascience/tidytuesday/tree/main/data/2023/2023-02-21)*

# %% [markdown]
# ###**Process Overview**

# %% [markdown]
# <p align = "justify"> The exploratory data analysis (EDA) on the datasets aimed to lay a solid groundwork for understanding the programming languages and paintings ecosystem from a macro perspective. This process began with standardizing the datasets, quality checks, and validating them to ensure structural consistency. This was followed by a descriptive analysis to investigate specific categorical and textual attributes, identify major patterns, and unveil overall trends in language attributes and origins. Summary statistics and distributional tests were used to confirm assumptions, reveal overall relationships, and validate dataset representativeness. In aggregate, these EDA activities sought to unify understanding from the datasets, minimize uncertainty, and lay the groundwork for using the data for analysis.

# %% [markdown]
# ###**Supplementary Material**

# %% [markdown]
# ####***Primary Dataset***

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# <br>
# **Top 10 Languages for Jobs:** This table shows what are the top 10 languages which have the higest number of jobs

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# <br>
#
# **Job vs User:** <p align="justify">most languages are tightly clustered near the lower-left corner, which suggests that the majority of languages have relatively low user counts and low job demand. At the same time, a few extreme outliers stand far away from the cluster, indicating that job postings and user adoption are heavily concentrated in a small number of dominant languages.

# %% [markdown]
# ![Screenshot 2026-01-28 at 9.14.10 PM.png](data:image/png;base64,...)
#
# **Github Stars vs Wikipedia Views:** <p align = "justify">There is a clear upward trend, meaning languages that have more GitHub stars generally also tend to have higher Wikipedia daily page views. However, the points are still fairly spread out, showing that the two popularity signals don’t align perfectly—some languages attract strong developer attention on GitHub while not being equally popular in general interest (Wikipedia), and vice versa.

# %% [markdown]
# ####***Backup Dataset***

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# **Evolution of Color Complexity Across Seasons:** <p align = "justify"> Average color complexity generally trends upward over seasons with noticeable fluctuations, suggesting gradual diversification.</p>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# **Color Count Distribution:** <p align = "justify"> The number of colors is concentrated around 11, with a roughly normal distribution centered near the mean, indicating most designs use a similar level of color complexity.</p>

# %% [markdown]
# ###**Use of Generative AI Tools**

# %% [markdown]
# In the development of this project, Generative AI tools—specifically **OpenAI’s ChatGPT** and **Google’s Gemini**—were utilized to augment the research and implementation process. The following sections outline the specific applications and the human oversight involved:<br><br>
#
# **1. Proposal and Conceptualization:**
# AI was used to structure the initial project proposal, helping to refine the scope and articulate the objectives clearly. It served as a brainstorming partner to ensure the project’s goals were comprehensive and well-aligned with the dataset's potential.<br><br>
#
# **2. Code Generation and Technical Implementation:**
# To expedite the coding process, **Gemini** was integrated with **Google Colab** to generate Python code snippets for data cleaning, type conversion, and visualization. These tools were instrumental in handling complex data manipulations, such as managing missing values and implementing logarithmic scaling for skewed distributions.<br><br>
#
# **3. Debugging and Error Rectification:**
# Both **ChatGPT** and **Gemini** were utilized as technical assistants to identify and resolve coding errors. By providing specific error logs to the AI, we were able to understand the underlying causes of runtime warnings (such as infinite values in log-scales) and apply robust fixes efficiently.<br><br>
#
# **4. Data Understanding and Domain Knowledge:**
# AI models were used to gain a deeper understanding of the `languages.csv` dataset. This included interpreting the significance of various metadata fields (e.g., Semantic Scholar citations vs. GitHub stars) and implementing specific EDA techniques to derive meaningful insights from the text and numeric data.<br><br>
#
# **Human Oversight and Responsibility:**
# While AI was used to generate initial drafts of code and text, all outputs were manually reviewed, validated, and edited by the authors. The final interpretation of results, the selection of visualization parameters, and the overall conclusions drawn from the data remain the sole responsibility of the project authors.

# %% [markdown]
# 1. [Generative AI Chat for Primary Dataset Content](https://gemini.google.com/share/b3c97ca266e6) <br>
# 2. [Generative AI Chat for Primary Dataset EDA](https://gemini.google.com/app/7f95f8aa1ba94fc2)
# 3. [Generative AI Chat for Backup Dataset EDA](https://chatgpt.com/share/697aae27-a2a0-800e-8e65-70cc233f36a0)<br>
# 4. [Generative AI Chat for Backup Dataset Content](https://chatgpt.com/share/697ab4c0-7da8-8000-9dec-62c2f5e1a5eb)<br>
